# %%
import pandas

# %%
pandas.test()
# Out:
# running: pytest --skip-slow --skip-network /Users/NewMaps/miniconda3/envs/exercise-01/lib/python3.7/site-packages/pandas
# ============================= test session starts =============================
# platform darwin -- Python 3.7.0, pytest-3.8.2, py-1.6.0, pluggy-0.7.1
# rootdir: /Users/NewMaps, inifile:
# collected 26971 items / 5 skipped
#
# ../../miniconda3/envs/exercise-01/lib/python3.7/site-packages/pandas/tests/test_algos.py . [  0%]
# .........................................................X............. [  0%]
# ...........s............................                                [  0%]
# ../../miniconda3/envs/exercise-01/lib/python3.7/site-packages/pandas/tests/test_base.py . [  0%]
# ....................................................................... [  0%]
# ....................................................................... [  0%]
# .......................................................x                [  1%]
# ...
